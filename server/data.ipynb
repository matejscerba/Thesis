# %%
import pandas as pd
import json

# %%
with open("data/main/mobile-phones/attributes.json", mode="r") as file:
    attributes = json.load(file)

# %%
df = pd.read_csv(f"data/main/mobile-phones/products.csv", sep=";")
df.head(5)
# Out:
#    id                                        name  Price [CZK]  \
# 0   0  Xiaomi Redmi Note 12 Pro 4G 8GB/256GB šedá         5790
# 1   1                    iPhone 13 128GB Midnight        16790
# 2   2           Samsung Galaxy S23 5G 256GB black        18790
# 3   3  Samsung Galaxy Z Flip5 8GB/512GB grafitová        24799
# 4   4           Samsung Galaxy A53 5G 128GB Black         7990
#
#    Price without VAT [CZK]  Rating  rating_count availability  \
# 0                   4785.0     4.9          31.0     In stock
# 1                  13876.0     4.8         577.0     In stock
# 2                  15529.0     4.8         103.0     In stock
# 3                  20495.0     5.0          17.0     In stock
# 4                   6603.0     4.6         113.0     In stock
#
#    Display size ["] Display resolution Operating system  ...  \
# 0              6.67     2400 × 1080 px      ['Android']  ...
# 1              6.10     2532 × 1170 px          ['iOS']  ...
# 2              6.10       2340x1080 px      ['Android']  ...
# 3              6.70     2640 × 1080 px      ['Android']  ...
# 4              6.50     2400 × 1080 px      ['Android']  ...
#
#   Second front camera resolution [Mpx] Secondary Front Camera Aperture [f/]  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    Second camera resolution with telephoto lens [Mpx]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Second camera aperture with telephoto lens [f/]  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Resistance against falls from max. height [m]  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Night vision resolution [Mpx] Night vision aperture [f/] Features  \
# 0                           NaN                        NaN      NaN
# 1                           NaN                        NaN      NaN
# 2                           NaN                        NaN      NaN
# 3                           NaN                        NaN      NaN
# 4                           NaN                        NaN      NaN
#
#   Processor model Third front camera resolution [Mpx]
# 0             NaN                                 NaN
# 1             NaN                                 NaN
# 2             NaN                                 NaN
# 3             NaN                                 NaN
# 4             NaN                                 NaN
#
# [5 rows x 91 columns]

# %%
for attribute in attributes:
    if attribute["full_name"] not in df.columns:
        print(attribute["full_name"])

# %%
# attributes = [attribute for attribute in attributes if attribute["full_name"] in df.columns]

# %%
# with open("data/main/mobile-phones/attributes.json", mode="w") as file:
#     json.dump(attributes, file, indent=4, ensure_ascii=False)

# %%
for column in df.columns:
    print()
    print(column)
    print(len(df[column]))
    print(len(df[df[column].isna()]))
# Out:
# id
# 1199
# 0
#
# name
# 1199
# 0
#
# Price [CZK]
# 1199
# 0
#
# Price without VAT [CZK]
# 1199
# 1
#
# Rating
# 1199
# 152
#
# rating_count
# 1199
# 152
#
# availability
# 1199
# 0
#
# Display size ["]
# 1199
# 1
#
# Display resolution
# 1199
# 3
#
# Operating system
# 1199
# 1
#
# Configure cards
# 1199
# 1
#
# Memory card slot
# 1199
# 2
#
# Rear camera resolution [Mpx]
# 1199
# 48
#
# Front camera resolution [Mpx]
# 1199
# 218
#
# Launched
# 1199
# 182
#
# Functions
# 1199
# 16
#
# Country
# 1199
# 635
#
# Type
# 1199
# 7
#
# Degree of protection
# 1199
# 551
#
# Gorilla Glass version
# 1199
# 890
#
# Height [mm]
# 1199
# 7
#
# Width [mm]
# 1199
# 7
#
# Depth [mm]
# 1199
# 7
#
# Weight [kg]
# 1199
# 11
#
# Colour
# 1199
# 12
#
# Display type
# 1199
# 28
#
# Display properties
# 1199
# 1051
#
# Display refresh rate [Hz]
# 1199
# 377
#
# Screen fineness [PPI]
# 1199
# 213
#
# Display brightness [Nits]
# 1199
# 695
#
# Shape of the cutout in the display
# 1199
# 133
#
# Camera type
# 1199
# 409
#
# Number of rear camera lenses
# 1199
# 36
#
# Number of front camera lenses
# 1199
# 224
#
# Main rear camera resolution [Mpx]
# 1199
# 36
#
# Main rear camera aperture [f/]
# 1199
# 304
#
# Wide-angle lens camera resolution [Mpx]
# 1199
# 594
#
# Wide-angle lens camera aperture [f/]
# 1199
# 636
#
# Macro camera resolution [Mpx]
# 1199
# 853
#
# Macro camera aperture [f/]
# 1199
# 912
#
# Depth camera resolution [Mpx]
# 1199
# 958
#
# Depth camera aperture [f/]
# 1199
# 1023
#
# Front Camera Resolution [Mpx]
# 1199
# 222
#
# Front Camera Aperture [f/]
# 1199
# 347
#
# Maximum Aperture [f/]
# 1199
# 386
#
# Maximum video resolution
# 1199
# 288
#
# Supported resolutions and frame rates (FPS)
# 1199
# 308
#
# Camera functions
# 1199
# 223
#
# Battery capacity [mAh]
# 1199
# 113
#
# Charging performance [W]
# 1199
# 370
#
# Replaceable battery
# 1199
# 74
#
# Computer memory (RAM) [GB]
# 1199
# 283
#
# Internal memory [GB]
# 1199
# 159
#
# Memory card type
# 1199
# 199
#
# Maximum memory card capacity [GB]
# 1199
# 488
#
# Processor brand
# 1199
# 935
#
# Number of processor cores
# 1199
# 190
#
# Processor frequency [GHz]
# 1199
# 390
#
# Processor tag
# 1199
# 183
#
# Graphic accelerator
# 1199
# 447
#
# Wireless technology
# 1199
# 26
#
# Data services
# 1199
# 76
#
# Primary SIM card type
# 1199
# 16
#
# Secondary SIM Card Type
# 1199
# 155
#
# Bluetooth version
# 1199
# 375
#
# Connectors
# 1199
# 1
#
# Sensors
# 1199
# 212
#
# Accessories Included
# 1199
# 92
#
# Operating system version
# 1199
# 235
#
# Extension
# 1199
# 556
#
# Remote Management (MDM)
# 1199
# 838
#
# Durability
# 1199
# 596
#
# Image stabilization
# 1199
# 367
#
# Optical zoom
# 1199
# 945
#
# Max wireless charging performance [W]
# 1199
# 956
#
# Processor designation
# 1199
# 459
#
# Telephoto camera resolution [Mpx]
# 1199
# 982
#
# Telephoto camera aperture [f/]
# 1199
# 991
#
# Max. reverse charging power [W]
# 1199
# 1113
#
# Calls via Internet
# 1199
# 939
#
# Virtual operating memory [GB]
# 1199
# 1100
#
# Second front camera resolution [Mpx]
# 1199
# 1178
#
# Secondary Front Camera Aperture [f/]
# 1199
# 1184
#
# Second camera resolution with telephoto lens [Mpx]
# 1199
# 1160
#
# Second camera aperture with telephoto lens [f/]
# 1199
# 1167
#
# Resistance against falls from max. height [m]
# 1199
# 1090
#
# Night vision resolution [Mpx]
# 1199
# 1180
#
# Night vision aperture [f/]
# 1199
# 1171
#
# Features
# 1199
# 1194
#
# Processor model
# 1199
# 1193
#
# Third front camera resolution [Mpx]
# 1199
# 1196

# %%
# df = df.drop(columns=[])

# %%
for column in df.columns:
    print()
    print(column)
    print(len(df[column]))
    print(len(df[df[column].isna()]))
# Out:
# id
# 1199
# 0
#
# name
# 1199
# 0
#
# Price [CZK]
# 1199
# 0
#
# Price without VAT [CZK]
# 1199
# 1
#
# Rating
# 1199
# 152
#
# rating_count
# 1199
# 152
#
# availability
# 1199
# 0
#
# Display size ["]
# 1199
# 1
#
# Display resolution
# 1199
# 3
#
# Operating system
# 1199
# 1
#
# Configure cards
# 1199
# 1
#
# Memory card slot
# 1199
# 2
#
# Rear camera resolution [Mpx]
# 1199
# 48
#
# Front camera resolution [Mpx]
# 1199
# 218
#
# Launched
# 1199
# 182
#
# Functions
# 1199
# 16
#
# Country
# 1199
# 635
#
# Type
# 1199
# 7
#
# Degree of protection
# 1199
# 551
#
# Gorilla Glass version
# 1199
# 890
#
# Height [mm]
# 1199
# 7
#
# Width [mm]
# 1199
# 7
#
# Depth [mm]
# 1199
# 7
#
# Weight [kg]
# 1199
# 11
#
# Colour
# 1199
# 12
#
# Display type
# 1199
# 28
#
# Display properties
# 1199
# 1051
#
# Display refresh rate [Hz]
# 1199
# 377
#
# Screen fineness [PPI]
# 1199
# 213
#
# Display brightness [Nits]
# 1199
# 695
#
# Shape of the cutout in the display
# 1199
# 133
#
# Camera type
# 1199
# 409
#
# Number of rear camera lenses
# 1199
# 36
#
# Number of front camera lenses
# 1199
# 224
#
# Main rear camera resolution [Mpx]
# 1199
# 36
#
# Main rear camera aperture [f/]
# 1199
# 304
#
# Wide-angle lens camera resolution [Mpx]
# 1199
# 594
#
# Wide-angle lens camera aperture [f/]
# 1199
# 636
#
# Macro camera resolution [Mpx]
# 1199
# 853
#
# Macro camera aperture [f/]
# 1199
# 912
#
# Depth camera resolution [Mpx]
# 1199
# 958
#
# Depth camera aperture [f/]
# 1199
# 1023
#
# Front Camera Resolution [Mpx]
# 1199
# 222
#
# Front Camera Aperture [f/]
# 1199
# 347
#
# Maximum Aperture [f/]
# 1199
# 386
#
# Maximum video resolution
# 1199
# 288
#
# Supported resolutions and frame rates (FPS)
# 1199
# 308
#
# Camera functions
# 1199
# 223
#
# Battery capacity [mAh]
# 1199
# 113
#
# Charging performance [W]
# 1199
# 370
#
# Replaceable battery
# 1199
# 74
#
# Computer memory (RAM) [GB]
# 1199
# 283
#
# Internal memory [GB]
# 1199
# 159
#
# Memory card type
# 1199
# 199
#
# Maximum memory card capacity [GB]
# 1199
# 488
#
# Processor brand
# 1199
# 935
#
# Number of processor cores
# 1199
# 190
#
# Processor frequency [GHz]
# 1199
# 390
#
# Processor tag
# 1199
# 183
#
# Graphic accelerator
# 1199
# 447
#
# Wireless technology
# 1199
# 26
#
# Data services
# 1199
# 76
#
# Primary SIM card type
# 1199
# 16
#
# Secondary SIM Card Type
# 1199
# 155
#
# Bluetooth version
# 1199
# 375
#
# Connectors
# 1199
# 1
#
# Sensors
# 1199
# 212
#
# Accessories Included
# 1199
# 92
#
# Operating system version
# 1199
# 235
#
# Extension
# 1199
# 556
#
# Remote Management (MDM)
# 1199
# 838
#
# Durability
# 1199
# 596
#
# Image stabilization
# 1199
# 367
#
# Optical zoom
# 1199
# 945
#
# Max wireless charging performance [W]
# 1199
# 956
#
# Processor designation
# 1199
# 459
#
# Telephoto camera resolution [Mpx]
# 1199
# 982
#
# Telephoto camera aperture [f/]
# 1199
# 991
#
# Max. reverse charging power [W]
# 1199
# 1113
#
# Calls via Internet
# 1199
# 939
#
# Virtual operating memory [GB]
# 1199
# 1100
#
# Second front camera resolution [Mpx]
# 1199
# 1178
#
# Secondary Front Camera Aperture [f/]
# 1199
# 1184
#
# Second camera resolution with telephoto lens [Mpx]
# 1199
# 1160
#
# Second camera aperture with telephoto lens [f/]
# 1199
# 1167
#
# Resistance against falls from max. height [m]
# 1199
# 1090
#
# Night vision resolution [Mpx]
# 1199
# 1180
#
# Night vision aperture [f/]
# 1199
# 1171
#
# Features
# 1199
# 1194
#
# Processor model
# 1199
# 1193
#
# Third front camera resolution [Mpx]
# 1199
# 1196

# %%
index = 55
for column in df.columns[index:index + 1]:
    print()
    print(column, df[column].dtype)
    if df[column].dtype == object:
        continue
    print(df[column].min(), df[df[column] == df[column].min()]["name"])
    print()
    print(df[column].max(), df[df[column] == df[column].max()]["name"])
# Out:
# Processor brand object

# %%
column_name = df.columns[index]

# %%
print(df[column_name].min())
df[df[column_name] == df[column_name].min()]
# Out:
# 22.0
#         id                                          name  Price [CZK]  \
# 214    214             Doogee S100 Pro 12GB/256 GB černá         8690
# 346    346  Doogee V MAX 5G DualSIM 12GB/256GB  stříbrná        12590
# 1040  1040             UleFone Armor 24 12GB/256GB černý         6799
#
#       Price without VAT [CZK]  Rating  rating_count  \
# 214                    7182.0     4.8           6.0
# 346                   10405.0     4.9           7.0
# 1040                   5619.0     NaN           NaN
#
#                     availability  Display size ["] Display resolution  \
# 214                     In stock              6.58     2408 × 1080 px
# 346             In stock > 5 pcs              6.58     2408 × 1080 px
# 1040  Expected December 15, 2023              6.78     2460 × 1080 px
#
#      Operating system  ... Second front camera resolution [Mpx]  \
# 214       ['Android']  ...                                  NaN
# 346       ['Android']  ...                                  NaN
# 1040      ['Android']  ...                                  NaN
#
#      Secondary Front Camera Aperture [f/]  \
# 214                                   NaN
# 346                                   NaN
# 1040                                  NaN
#
#       Second camera resolution with telephoto lens [Mpx]  \
# 214                                                 NaN
# 346                                                 NaN
# 1040                                                NaN
#
#       Second camera aperture with telephoto lens [f/]  \
# 214                                               NaN
# 346                                               NaN
# 1040                                              NaN
#
#       Resistance against falls from max. height [m]  \
# 214                                             2.0
# 346                                             1.5
# 1040                                            1.5
#
#      Night vision resolution [Mpx] Night vision aperture [f/] Features  \
# 214                            NaN                       1.80      NaN
# 346                           20.0                        NaN      NaN
# 1040                           NaN                       1.79      NaN
#
#      Processor model Third front camera resolution [Mpx]
# 214              NaN                                 NaN
# 346              NaN                                 NaN
# 1040             NaN                                 NaN
#
# [3 rows x 91 columns]

# %%
df.loc[(df[column_name] < 100) & (df["name"].str.startswith("", na=False)), column_name] = df[column_name] * 1000

# %%
df.to_csv(f"data/main/mobile-phones/products.csv", sep=";", index=False)
